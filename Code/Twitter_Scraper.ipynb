# %% [markdown]
# # Twitter scraping

# %%
# Install Twitter Scraper
# !pip install twitterscraper

# %%
from twitterscraper import query_tweets
import pandas as pd
import datetime, time
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; x64; fr; rv:1.9.2.13) Gecko/20101203 Firebird/3.6.13'}

# %%
# initialize a time counter
t0 = time.time()

# create a list of locations to scrape twitter in
locations = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# set empty lists that we will fill with tweet data
text = []
locs = []
usernames = []
times = []
rt = []
likes = []

# loop through each place in the locations list
for place in locations:
    
    # scrape twitter for tweets containing certain keywords 
    query_string = f'"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"{place}" within:15mi -filter:retweets'
    list_of_tweets = query_tweets(query_string,
                            begindate = datetime.date(2014,1,1),
                            enddate = datetime.date(2019,12,31),
                            poolsize = 2,
                            lang="en"
                           )
    
    # loop through each tweet to grab data and append the data to their respective lists
    for tweet in list_of_tweets:
        locs.append(place)
        text.append(tweet.text)
        usernames.append(tweet.username)
        times.append(tweet.timestamp)
        rt.append(tweet.retweets)
        likes.append(tweet.likes)

# build the dataframe 
df = pd.DataFrame({
    'tweet': text,
    'location': locs,
    'user_name': usernames,
    'time_stamp': times,
    'num_retweets': rt,
    'num_likes': likes
})

print((time.time()-t0)/60)
# Out:
# INFO: queries: ['"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alabama" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31', '"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alabama" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alabama" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alabama" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 83.13.164.202:41734
# INFO: Using proxy 83.13.164.202:41734
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 181.112.225.78:35482
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1188585437658525696-1189969617516662784&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 181.112.225.78:35482
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwLXNj4ra_iAWgMC0mf_Dz4MhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 186.211.182.113:38934
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-783349603387248643-783349603387248643&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 186.211.182.113:38934
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 1 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31.
# INFO: Got 1 tweets (1 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLbFhPeK-SAWgMC0mf_Dz4MhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 27.147.255.12:32589
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 57 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alabama"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31.
# INFO: Got 58 tweets (57 new).
# INFO: queries: ['"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alaska" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31', '"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alaska" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alaska" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Alaska" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31
# INFO: Using proxy 83.13.164.202:41734
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 83.13.164.202:41734
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-517443708825116672-577883856965099520&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 181.112.225.78:35482
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1187260128162144256-1189741265165967360&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 181.112.225.78:35482
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwMGI_cCXhQ4WgICz_cuTh4UQEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 186.211.182.113:38934
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLex-rL_-SAWgIC7zZHY54IhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 186.211.182.113:38934
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwJLUtvzvgwwWgICz_cuTh4UQEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 27.147.255.12:32589
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 11 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31.
# INFO: Got 11 tweets (11 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwLTV3Mqm-CAWgIC7zZHY54IhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 27.147.255.12:32589
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 43 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Alaska"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31.
# INFO: Got 54 tweets (43 new).
# INFO: queries: ['"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Arizona" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31', '"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Arizona" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Arizona" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Arizona" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 83.13.164.202:41734
# INFO: Using proxy 83.13.164.202:41734
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 181.112.225.78:35482
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1187847572678828032-1189941733305417729&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 181.112.225.78:35482
# INFO: Retrying... (Attempts left: 49)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 186.211.182.113:38934
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKeN3cSK_CAWgoCo0fXswoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 186.211.182.113:38934
# INFO: Retrying... (Attempts left: 48)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 27.147.255.12:32589
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEwKDt2MSx-iAWgoCo0fXswoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 27.147.255.12:32589
# INFO: Retrying... (Attempts left: 47)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 92.247.2.26:21231
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 43 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31.
# INFO: Got 43 tweets (43 new).
# INFO: Retrying... (Attempts left: 46)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 80.32.122.118:60971
# INFO: Retrying... (Attempts left: 45)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 154.117.155.42:33219
# INFO: Retrying... (Attempts left: 44)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 62.24.109.89:60045
# INFO: Retrying... (Attempts left: 43)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 103.250.153.202:54028
# INFO: Retrying... (Attempts left: 42)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 80.90.25.160:40945
# INFO: Retrying... (Attempts left: 41)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 198.50.152.64:23500
# INFO: Retrying... (Attempts left: 40)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 212.87.248.11:40762
# INFO: Retrying... (Attempts left: 39)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 188.235.107.7:60205
# INFO: Retrying... (Attempts left: 38)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 187.216.90.46:53281
# INFO: Retrying... (Attempts left: 37)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 116.0.2.162:54070
# INFO: Retrying... (Attempts left: 36)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 182.52.51.48:42511
# INFO: Retrying... (Attempts left: 35)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 103.241.227.116:37774
# INFO: Retrying... (Attempts left: 34)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 36.89.180.245:57290
# INFO: Retrying... (Attempts left: 33)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 182.191.84.39:80
# INFO: Retrying... (Attempts left: 32)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 181.129.140.226:38681
# INFO: Retrying... (Attempts left: 31)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 95.131.91.130:60944
# INFO: Retrying... (Attempts left: 30)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 125.25.54.65:57689
# INFO: Retrying... (Attempts left: 29)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 168.195.228.114:46387
# INFO: Retrying... (Attempts left: 28)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 103.216.82.44:8080
# INFO: Retrying... (Attempts left: 27)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 177.12.80.50:50556
# INFO: Retrying... (Attempts left: 26)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 119.15.82.222:37790
# INFO: Retrying... (Attempts left: 25)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 195.46.167.2:3128
# INFO: Retrying... (Attempts left: 24)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 37.111.42.210:8080
# INFO: Retrying... (Attempts left: 23)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 181.113.131.98:47961
# INFO: Retrying... (Attempts left: 22)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 195.206.42.41:48655
# INFO: Retrying... (Attempts left: 21)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 36.89.181.183:31227
# INFO: Retrying... (Attempts left: 20)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 83.17.171.250:57087
# INFO: Retrying... (Attempts left: 19)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Arizona"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 87.255.27.163:3128
# INFO: Retrying... (Attempts left: 18)
# ...
# INFO: Using proxy 181.112.225.78:35482
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKLtw5mAwBMWgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 186.211.182.113:38934
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgL_Bse-I-yAWioCjge6ypoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 186.211.182.113:38934
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaIwLfFwqC6_BEWgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 27.147.255.12:32589
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLaVnuvFxiAWioCjge6ypoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 27.147.255.12:32589
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwJC4-er03g8WgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 92.247.2.26:21231
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEgLbxh_WUgCAWioCjge6ypoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 92.247.2.26:21231
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwL3F8-6VvR8WioCjge6ypoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 80.32.122.118:60971
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgMDkpuKe9w4WgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 80.32.122.118:60971
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLaVr5Sx7R4WioCjge6ypoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 154.117.155.42:33219
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgML8q7amlw4WgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 154.117.155.42:33219
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwLWVx7Ttwh4WioCjge6ypoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 62.24.109.89:60045
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwMOEybGk-Q0WgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 62.24.109.89:60045
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKO5mqmXvh4WioCjge6ypoMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 103.250.153.202:54028
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwMKQ7dWBpw0WgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 103.250.153.202:54028
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 89 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31.
# INFO: Got 89 tweets (89 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwJCgwIX16gwWgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 80.90.25.160:40945
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEwJHskfjirgwWgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 198.50.152.64:23500
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgJHIqdjkzQsWgMCziYCQivUVEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 212.87.248.11:40762
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 184 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Wyoming"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31.
# INFO: Got 273 tweets (184 new).
# 55.96927521626154

# %%
df.head()
# Out:
#                                                tweet location  \
# 0  Cheerleaders working during the blackout @ Cla...  Alabama
# 1                                 It’s spooky season  Alabama
# 2  Newsom Raked In Big Money From Public Utility ...  Alabama
# 3  Hope you don’t live in certain areas of Califo...  Alabama
# 4  Lmao nigga gone blackout off one  https://twit...  Alabama
#
#          user_name          time_stamp  num_retweets  num_likes
# 0     OD_Slaughter 2016-10-04 16:54:34             0          0
# 1   OMGItsBlackout 2019-10-31 18:17:20             0          0
# 2       deenie7940 2019-10-31 13:58:11             0          0
# 3     LarryGreer20 2019-10-30 19:46:29             0          2
# 4  YUNGINOJAWBREAK 2019-10-30 18:52:13             0          0

# %%
df.shape
# Out:
# (17499, 6)

# %%
df.describe()
# Out:
#        num_retweets     num_likes
# count  17499.000000  17499.000000
# mean       2.381450      8.530659
# std       66.453075    258.955016
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      2.000000
# max     5988.000000  23763.000000

# %%
df['location'].value_counts()
# Out:
# New York          7433
# Washington        2277
# California        1661
# Massachusetts     1284
# Georgia            499
# South Carolina     476
# Michigan           410
# Texas              353
# Wyoming            273
# Oregon             264
# Oklahoma           261
# Rhode Island       183
# Maryland           177
# Tennessee          162
# Pennsylvania       134
# Ohio               117
# Missouri           112
# Kentucky           107
# Connecticut         99
# Minnesota           90
# Delaware            87
# Florida             85
# Louisiana           77
# Utah                72
# Kansas              67
# New Jersey          60
# Mississippi         59
# Alabama             58
# Maine               57
# Alaska              54
# Colorado            53
# Arkansas            52
# Nevada              49
# Virginia            46
# Arizona             43
# Iowa                43
# Nebraska            30
# Idaho               28
# Vermont             25
# Hawaii              23
# Indiana             16
# Montana             12
# New Hampshire       10
# New Mexico           6
# South Dakota         6
# West Virginia        5
# Wisconsin            4
# Name: location, dtype: int64

# %%
print([tweet for tweet in df['tweet'][:5]])
# Out:
# ['Cheerleaders working during the blackout @ Clarence High School (Clarence, New York) https://www.instagram.com/p/BLJgBR3jKOq/\xa0', 'It’s spooky season', 'Newsom Raked In Big Money From Public Utility He Is Now Chiding For Fires And Rolling Blackouts https://townhall.com/tipsheet/bethbaumann/2019/10/30/newsom-raked-in-big-money-from-public-utility-he-is-now-chiding-for-fires-and-rol-n2555643\xa0…', 'Hope you don’t live in certain areas of California. Kinda hard to charge it when the power is out.', 'Lmao nigga gone blackout off one  https://twitter.com/trezmane/status/1189273044289757185\xa0…']

# %%
# add a word count column
df['tweet_word_count'] = df['tweet'].apply(lambda post: len(post.split()))

# %%
df.head()
# Out:
#                                                tweet location  \
# 0  Cheerleaders working during the blackout @ Cla...  Alabama
# 1                                 It’s spooky season  Alabama
# 2  Newsom Raked In Big Money From Public Utility ...  Alabama
# 3  Hope you don’t live in certain areas of Califo...  Alabama
# 4  Lmao nigga gone blackout off one  https://twit...  Alabama
#
#          user_name          time_stamp  num_retweets  num_likes  \
# 0     OD_Slaughter 2016-10-04 16:54:34             0          0
# 1   OMGItsBlackout 2019-10-31 18:17:20             0          0
# 2       deenie7940 2019-10-31 13:58:11             0          0
# 3     LarryGreer20 2019-10-30 19:46:29             0          2
# 4  YUNGINOJAWBREAK 2019-10-30 18:52:13             0          0
#
#    tweet_word_count
# 0                13
# 1                 3
# 2                19
# 3                19
# 4                 8

# %%
# save the dataframe file
df.to_csv('../Data/twitter_states_2014_19.csv', index=False)

# %%
df['time_stamp'].sort_values()
# Out:
# 13337   2014-01-01 00:32:02
# 8475    2014-01-01 01:06:37
# 4569    2014-01-01 01:26:18
# 14030   2014-01-01 01:49:04
# 4568    2014-01-01 01:52:30
#                 ...
# 14940   2019-10-31 19:01:50
# 8496    2019-10-31 19:12:04
# 8476    2019-10-31 19:12:04
# 14464   2019-10-31 19:15:30
# 14444   2019-10-31 19:15:30
# Name: time_stamp, Length: 17499, dtype: datetime64[ns]
