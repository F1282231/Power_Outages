# %% [markdown]
# # Twitter scraping

# %%
# Install Twitter Scraper
# !pip install twitterscraper

# %%
from twitterscraper import query_tweets
import pandas as pd
import datetime, time
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (compatible, MSIE 11, Windows NT 6.3; Trident/7.0; rv:11.0) like Gecko'}

# %% [markdown]
# we should get a list of words people use when talking about power outages.
# we also can't filter by multiple cities/states at the same time and they are dependent on what the user's location is set to.
# we might want to get a list of locations that we can check one at a time, then combine them all

# %%
# initialize a time counter
t0 = time.time()

# create a list of locations to scrape twitter in
locations = ['Los Angeles', 'San Fransisco', 'San Diego', 'San Jose', 'Fresno', 
             'Long Beach', 'Sacramento', 'Oakland', 'Santa Ana', 'Anaheim',
            'california']

# set empty lists that we will fill with tweet data
text = []
locs = []
usernames = []
times = []
rt = []
likes = []

# loop through each place in the locations list
for place in locations:
    
    # scrape twitter for tweets containing certain keywords 
    query_string = f'"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"{place}" within:15mi -filter:retweets'
    list_of_tweets = query_tweets(query_string,
                            begindate = datetime.date(2019,1,1),
                            enddate = datetime.date(2019,12,31),
                            poolsize = 2,
                            lang="en"
                           )
    
    # loop through each tweet to grab data and append the data to their respective lists
    for tweet in list_of_tweets:
        locs.append(place)
        text.append(tweet.text)
        usernames.append(tweet.username)
        times.append(tweet.timestamp)
        rt.append(tweet.retweets)
        likes.append(tweet.likes)

# build the dataframe 
df = pd.DataFrame({
    'tweet': text,
    'location': locs,
    'user_name': usernames,
    'time_stamp': times,
    'num_retweets': rt,
    'num_likes': likes
})

print((time.time()-t0)/60)
# Out:
# INFO: queries: ['"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Los Angeles" within:15mi -filter:retweets since:2019-01-01 until:2019-07-02', '"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Los Angeles" within:15mi -filter:retweets since:2019-07-02 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Los Angeles" within:15mi -filter:retweets since:2019-07-02 until:2019-12-31
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Los Angeles" within:15mi -filter:retweets since:2019-01-01 until:2019-07-02
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 151.253.165.70:8080
# INFO: Using proxy 151.253.165.70:8080
# INFO: Retrying... (Attempts left: 50)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 103.250.166.4:6666
# INFO: Retrying... (Attempts left: 49)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 138.121.32.26:23500
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1189281676465188865-1189312533317992455&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 103.250.166.4:6666
# INFO: Retrying... (Attempts left: 48)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 217.150.77.31:53281
# INFO: Retrying... (Attempts left: 47)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 151.232.72.19:80
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwLX5xtiWgSEWjoC2tdTcpIEhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 138.121.32.26:23500
# INFO: Retrying... (Attempts left: 46)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 85.43.127.116:80
# INFO: Retrying... (Attempts left: 45)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 119.28.118.116:1080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLfl5veGgSEWjoC2tdTcpIEhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 217.150.77.31:53281
# INFO: Retrying... (Attempts left: 44)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 5.141.81.65:61853
# INFO: Retrying... (Attempts left: 43)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 193.233.9.167:38155
# INFO: Retrying... (Attempts left: 42)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 150.107.243.18:41787
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwLTJ-5n5gCEWjoC2tdTcpIEhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 151.232.72.19:80
# INFO: Retrying... (Attempts left: 41)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 203.77.239.18:37002
# INFO: Retrying... (Attempts left: 40)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 1.10.188.140:43327
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEgLepnOjYgCEWjoC2tdTcpIEhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 85.43.127.116:80
# INFO: Retrying... (Attempts left: 39)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 191.98.198.45:40363
# INFO: Retrying... (Attempts left: 38)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 119.82.249.4:46641
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwLr1gIifgCEWjoC2tdTcpIEhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 119.28.118.116:1080
# INFO: Retrying... (Attempts left: 37)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 36.90.208.198:58912
# INFO: Retrying... (Attempts left: 36)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 188.252.64.154:60446
# INFO: Retrying... (Attempts left: 35)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 1.20.100.111:30095
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKOx44uQgCEWjoC2tdTcpIEhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 5.141.81.65:61853
# INFO: Retrying... (Attempts left: 34)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 62.85.52.95:53281
# INFO: Retrying... (Attempts left: 33)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 118.97.235.234:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKKNy430_yAWjoC2tdTcpIEhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 193.233.9.167:38155
# INFO: Retrying... (Attempts left: 32)
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy
tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"california"%20within%3A15mi%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31.
# INFO: Got 1441 tweets (1441 new).
# 11.788139454523723

# %%
df.head()
# Out:
#                                                tweet     location  \
# 0  Come on over, the weather is great! \n\n(just ...  Los Angeles
# 1  California blackouts of the past. \n\nIn 1941,...  Los Angeles
# 2  blackout miggs coming soon pic.twitter.com/J3D...  Los Angeles
# 3  California Blackouts Hit Cellphone Service, Fr...  Los Angeles
# 4  Breaking News: PG&E failed to notify 23,000 of...  Los Angeles
#
#          user_name          time_stamp  num_retweets  num_likes
# 0       steveendow 2019-10-29 22:46:18             0          0
# 1         SaulKQED 2019-10-29 22:41:11             0          0
# 2        _roxyroxx 2019-10-29 22:34:24             1          1
# 3    mattsheffield 2019-10-29 22:33:32             2          0
# 4  REDRealEstateLA 2019-10-29 22:11:29             0          0

# %%
df.shape
# Out:
# (7438, 6)

# %%
df.describe()
# Out:
#        num_retweets    num_likes
# count   7438.000000  7438.000000
# mean       2.925114     8.769293
# std       34.179684    93.552846
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     1.000000
# 75%        1.000000     3.000000
# max     1615.000000  5063.000000

# %%
df['location'].value_counts()
# Out:
# Oakland          1662
# San Fransisco    1657
# california       1441
# Los Angeles       887
# Sacramento        417
# San Jose          328
# Anaheim           328
# Long Beach        326
# San Diego         257
# Fresno             85
# Santa Ana          50
# Name: location, dtype: int64

# %%
print([tweet for tweet in df['tweet'][:5]])
# Out:
# ['Come on over, the weather is great! \n\n(just ignore the fires and massive blackouts)', 'California blackouts of the past. \n\nIn 1941, after the attack on Pearl Harbor, "Los Angeles Times" reporters and editors work in a dimly lit newsroom.  Authorities imposed  blackouts on the West Coast for fear of a possible Japanese assault. (Photo: Los Angeles Times Archives) pic.twitter.com/fl0aAFAngt', 'blackout miggs coming soon pic.twitter.com/J3D0pEK7m9', 'California Blackouts Hit Cellphone Service, Fraying a Lifeline http://dlvr.it/RHDDtY\xa0pic.twitter.com/Vyz6aBRKc3', 'Breaking News: PG&E failed to notify 23,000 of blackouts; CPUC launches probe of utility power outages: https://pb.fyi/60du\xa0']

# %%
# add a word count column
df['tweet_word_count'] = df['tweet'].apply(lambda post: len(post.split()))

# %%
df.head()
# Out:
#                                                tweet     location  \
# 0  Come on over, the weather is great! \n\n(just ...  Los Angeles
# 1  California blackouts of the past. \n\nIn 1941,...  Los Angeles
# 2  blackout miggs coming soon pic.twitter.com/J3D...  Los Angeles
# 3  California Blackouts Hit Cellphone Service, Fr...  Los Angeles
# 4  Breaking News: PG&E failed to notify 23,000 of...  Los Angeles
#
#          user_name          time_stamp  num_retweets  num_likes  \
# 0       steveendow 2019-10-29 22:46:18             0          0
# 1         SaulKQED 2019-10-29 22:41:11             0          0
# 2        _roxyroxx 2019-10-29 22:34:24             1          1
# 3    mattsheffield 2019-10-29 22:33:32             2          0
# 4  REDRealEstateLA 2019-10-29 22:11:29             0          0
#
#    tweet_word_count
# 0                14
# 1                45
# 2                 5
# 3                10
# 4                17

# %%
# save the dataframe file
df.to_csv('../Data/twitter.csv', index=False)
