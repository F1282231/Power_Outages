# %% [markdown]
# # Twitter scraping

# %%
# Install Twitter Scraper
# !pip install twitterscraper

# %%
from twitterscraper import query_tweets
import pandas as pd
import datetime, time
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; rv:2.2) Gecko/20110201'}

# %% [markdown]
# we should get a list of words people use when talking about power outages.
# we also can't filter by multiple cities/states at the same time and they are dependent on what the user's location is set to.
# we might want to get a list of locations that we can check one at a time, then combine them all

# %%
# initialize a time counter
t0 = time.time()

# create a list of locations to scrape twitter in
locations = ["Alabama","Alaska","Arizona","Arkansas","California","Colorado",
  "Connecticut","Delaware","Florida","Georgia","Hawaii","Idaho","Illinois",
  "Indiana","Iowa","Kansas","Kentucky","Louisiana","Maine","Maryland",
  "Massachusetts","Michigan","Minnesota","Mississippi","Missouri","Montana",
  "Nebraska","Nevada","New Hampshire","New Jersey","New Mexico","New York",
  "North Carolina","North Dakota","Ohio","Oklahoma","Oregon","Pennsylvania",
  "Rhode Island","South Carolina","South Dakota","Tennessee","Texas","Utah",
  "Vermont","Virginia","Washington","West Virginia","Wisconsin","Wyoming"]

# set empty lists that we will fill with tweet data
text = []
locs = []
usernames = []
times = []
rt = []
likes = []

# loop through each place in the locations list
for place in locations:
    
    # scrape twitter for tweets containing certain keywords 
    query_string = f'"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"{place}" within:15mi -filter:retweets'
    list_of_tweets = query_tweets(query_string,
                            begindate = datetime.date(2014,1,1),
                            enddate = datetime.date(2019,12,31),
                            poolsize = 2,
                            lang="en"
                           )
    
    # loop through each tweet to grab data and append the data to their respective lists
    for tweet in list_of_tweets:
        locs.append(place)
        text.append(tweet.text)
        usernames.append(tweet.username)
        times.append(tweet.timestamp)
        rt.append(tweet.retweets)
        likes.append(tweet.likes)

# build the dataframe 
df = pd.DataFrame({
    'tweet': text,
    'location': locs,
    'user_name': usernames,
    'time_stamp': times,
    'num_retweets': rt,
    'num_likes': likes
})

print((time.time()-t0)/60)
# Out:
# INFO: queries: ['"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Los Angeles" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31', '"power outage" OR "power is out" OR "power\'s out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Los Angeles" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Los Angeles" within:15mi -filter:retweets since:2014-01-01 until:2016-12-31
# INFO: Querying "power outage" OR "power is out" OR "power's out" OR "blackouts" OR "blackout" -"video game" OR "power failure" OR "power failures" OR "no electricity" OR "power shortage" OR "electrical failure" OR "power loss" OR "power cuts" OR "power cut" OR "power went out" OR "power interuption" OR "brownout" OR "power goes out" OR "brownouts" OR "without power" near:"Los Angeles" within:15mi -filter:retweets since:2016-12-31 until:2019-12-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 103.250.153.199:43369
# INFO: Using proxy 103.250.153.199:43369
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1189912754334777349-1189945787071025152&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 181.48.47.26:53281
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-797161635810942976-812832602713362432&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 181.48.47.26:53281
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaKgKa9j9a1gyEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 95.129.97.13:34706
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKrdvI3ygiEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 95.31.5.29:54651
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKWxmJKLkBYWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 95.129.97.13:34706
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEgKjxvK3bgiEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 103.251.225.13:34052
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLzFrrqT0RUWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 95.31.5.29:54651
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKOB6KnFgiEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 95.87.14.245:41258
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKfN4pK4giEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 103.8.40.129:55050
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLCV_fbcmRUWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 103.251.225.13:34052
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKLRvpyqgiEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 82.147.120.38:42128
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLK165rH1RQWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 95.87.14.245:41258
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKfVlbObgiEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 1.10.186.114:39727
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKr545-IgiEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 46.0.203.186:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKHNhMLS9hMWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 103.8.40.129:55050
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwL6N5PHdgSEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 36.89.191.73:23500
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKLN3IHGgSEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 217.30.78.53:53281
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLal0sPixRMWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 82.147.120.38:42128
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwL6977eugSEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 103.203.173.149:49068
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLLdlLXCoRMWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 1.10.186.114:39727
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwLz9icuegSEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 138.97.116.174:57537
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaKgLbFofKC-RIWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 46.0.203.186:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLfhw6SPgSEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 86.110.172.54:40512
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKX159GY2BIWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 36.89.191.73:23500
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLeBp6eBgSEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 181.196.205.250:54024
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLH5xuDssxIWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 217.30.78.53:53281
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKCJj7LzgCEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 114.6.88.238:60811
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKP1vvaynxIWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy 103.203.173.149:49068
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKOV9r6ugCEWgMC6xfDYxIMhEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2016-12-31%20until%3A2019-12-31&l=en
# INFO: Using proxy 118.151.209.214:39338
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKiVvs7IjxIWgMCwqcK84ccWEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"power's%20out"%20OR%20"blackouts"%20OR%20"blackout"%20-"video%20game"%20OR%20"power%20failure"%20OR%20"power%20failures"%20OR%20"no%20electricity"%20OR%20"power%20shortage"%20OR%20"electrical%20failure"%20OR%20"power%20loss"%20OR%20"power%20cuts"%20OR%20"power%20cut"%20OR%20"power%20went%20out"%20OR%20"power%20interuption"%20OR%20"brownout"%20OR%20"power%20goes%20out"%20OR%20"brownouts"%20OR%20"without%20power"%20near%3A"Los%20Angeles"%20within%3A15mi%20-filter%3Aretweets%20since%3A2014-01-01%20until%3A2016-12-31&l=en
# INFO: Using proxy
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.000000      2.000000
# max     6917.000000  42148.000000

# %%
df['location'].value_counts()
# Out:
# Los Angeles      4566
# Oakland          3506
# San Fransisco    3381
# Anaheim          1904
# Long Beach       1687
# california       1657
# San Diego        1094
# San Jose          992
# Santa Ana         981
# Sacramento        841
# Fresno            248
# Name: location, dtype: int64

# %%
print([tweet for tweet in df['tweet'][:5]])
# Out:
# ["Power's out at home...so it's movie time! (@ ArcLight Cinemas for La La Land in Los Angeles, CA) https://www.swarmapp.com/c/jOZ6zO1b4vV\xa0", 'First #raindrops in the new ride! #mazzy #windshield #blackout #sprinkles #contrast #minim_cat… https://www.instagram.com/p/BOTiMVFBsS4/\xa0', 'STORY: LAX impacted by power outage in area http://abc7.la/2i5fOis\xa0', 'The power is out in Westwood so we are practicing lashes in the natural light of the experience… https://www.instagram.com/p/BOIrh2_luLX/\xa0', 'When the power is out at work... @ Atwater Village, Los Angeles https://www.instagram.com/p/BN5oUUojSoU2Fp0jfRKLerqUnaat0dsGOzcpsQ0/\xa0…']

# %%
# add a word count column
df['tweet_word_count'] = df['tweet'].apply(lambda post: len(post.split()))

# %%
df.head()
# Out:
#                                                tweet     location  \
# 0  Power's out at home...so it's movie time! (@ A...  Los Angeles
# 1  First #raindrops in the new ride! #mazzy #wind...  Los Angeles
# 2  STORY: LAX impacted by power outage in area ht...  Los Angeles
# 3  The power is out in Westwood so we are practic...  Los Angeles
# 4  When the power is out at work... @ Atwater Vil...  Los Angeles
#
#          user_name          time_stamp  num_retweets  num_likes  \
# 0        waynesfca 2016-12-25 01:29:28             0          1
# 1       hlgraphics 2016-12-22 04:00:09             0          0
# 2     LosAngelesCP 2016-12-19 05:42:08             0          0
# 3  avedalosangeles 2016-12-17 22:50:06             0          0
# 4   yvette_nicole5 2016-12-12 02:33:24             0          1
#
#    tweet_word_count
# 0                19
# 1                13
# 2                 9
# 3                19
# 4                14

# %%
# save the dataframe file
df.to_csv('../Data/twitter_states_2014_19.csv', index=False)

# %%
df['time_stamp'].sort_values()
# Out:
# 2261    2014-01-01 00:14:03
# 9419    2014-01-01 00:45:30
# 9418    2014-01-01 01:54:05
# 12219   2014-01-01 01:57:45
# 2260    2014-01-01 02:04:16
#                 ...
# 7947    2019-10-31 17:05:38
# 19201   2019-10-31 17:11:16
# 19221   2019-10-31 17:11:16
# 19200   2019-10-31 17:19:27
# 19220   2019-10-31 17:19:27
# Name: time_stamp, Length: 20857, dtype: datetime64[ns]
