# %% [markdown]
# # Twitter scraping

# %%
# Install Twitter Scraper
# !pip install twitterscraper

# %%
from twitterscraper import query_tweets
import pandas as pd
import datetime, time
# Out:
# INFO: {'User-Agent': 'Opera/9.80 (X11; Linux i686; Ubuntu/14.10) Presto/2.12.388 Version/12.16'}

# %% [markdown]
# we should get a list of words people use when talking about power outages.
# we also can't filter by multiple cities/states at the same time and they are dependent on what the user's location is set to.
# we might want to get a list of locations that we can check one at a time, then combine them all

# %%
# initialize a time counter
t0 = time.time()

# create a list of locations to scrape twitter in
locations = ['Los Angeles', 'San Fransisco', 'San Diego', 'San Jose', 'Fresno', 
             'Long Beach', 'Sacramento', 'Oakland', 'Santa Ana', 'Anaheim']

# set empty lists that we will fill with tweet data
text = []
locs = []
usernames = []
times = []
rt = []
likes = []

# loop through each place in the locations list
for place in locations:
    
    # scrape twitter for tweets containing certain keywords 
    query_string = f'"power outage" OR "power is out" OR "no power" OR "power\'s out" near:"{place}" -filter:retweets'
    list_of_tweets = query_tweets(query_string,
                            begindate = datetime.date(2019,1,1),
                            enddate = datetime.date(2019,12,31),
                            poolsize = 2,
                            lang="en"
                           )
    
    # loop through each tweet to grab data and append the data to their respective lists
    for tweet in list_of_tweets:
        locs.append(place)
        text.append(tweet.text)
        usernames.append(tweet.username)
        times.append(tweet.timestamp)
        rt.append(tweet.retweets)
        likes.append(tweet.likes)

# build the dataframe 
df = pd.DataFrame({
    'tweet': text,
    'location': locs,
    'user_name': usernames,
    'time_stamp': times,
    'num_retweets': rt,
    'num_likes': likes
})

print((time.time()-t0)/60)
# Out:
# INFO: queries: ['"power outage" OR "power is out" OR "no power" OR "power\'s out" near:"Los Angeles" -filter:retweets since:2019-01-01 until:2019-07-02', '"power outage" OR "power is out" OR "no power" OR "power\'s out" near:"Los Angeles" -filter:retweets since:2019-07-02 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "no power" OR "power's out" near:"Los Angeles" -filter:retweets since:2019-01-01 until:2019-07-02
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 14.162.146.38:52385
# INFO: Querying "power outage" OR "power is out" OR "no power" OR "power's out" near:"Los Angeles" -filter:retweets since:2019-07-02 until:2019-12-31
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 14.162.146.38:52385
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1188482031803650048-1188638567913984000&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 130.255.137.53:45128
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1140499864440066048-1145788309345464321&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 130.255.137.53:45128
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwLr5jYer_iAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 91.214.240.19:58987
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKahy4L20x8WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 91.214.240.19:58987
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKDJ24rX_SAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 178.222.249.230:41493
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKfh3cyh_SAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 110.34.28.30:55771
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEwKPFw9e7yR8WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 178.222.249.230:41493
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKeBq-C8_CAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 111.118.155.80:53990
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKfx3brIxR8WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 110.34.28.30:55771
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLepwPbw-yAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 103.75.209.75:55400
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgK_t_eP7vR8WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 111.118.155.80:53990
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKjJ18aF-yAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 89.109.239.183:47837
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKfZzcnf-iAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 146.88.51.235:80
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLfhhNuo_B4WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 103.75.209.75:55400
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEwKeB0-qr-iAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 217.182.51.229:1080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwL3R8PKe_B4WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 89.109.239.183:47837
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKLRzLOt-SAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 118.174.232.44:38093
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKfdjZi7-CAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 183.91.33.42:8087
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKOpi9K79R4WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 146.88.51.235:80
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKbtsvnZ9yAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 201.182.223.16:37492
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKi1hLCU9iAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 180.250.54.27:53281
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKeJ24bw3x4WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 217.182.51.229:1080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKalmc-_9SAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 12.31.192.18:1337
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEgKf9hMOg2B4WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 118.174.232.44:38093
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLvV96ap9CAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 95.134.195.78:48935
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwL7R8Mydzx4WgsCn5bGZ1OYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 183.91.33.42:8087
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKeNgteU8yAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 186.159.112.6:53281
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 198 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02.
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgLWNlNC-6iAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 167.71.2.61:3128
# INFO: Got 198 tweets (198 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEwKLx7Pje5yAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 45.7.205.103:43500
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgLuppYOs3SAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 199.247.22.236:33244
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKaVm8vN0SAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 125.25.136.63:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKOB_ZzxvyAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 212.66.127.242:41258
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaIwKK1iaWWtyAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 91.135.194.22:36374
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKrhh-PupiAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 41.190.33.162:8080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKaZo6zhmyAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 93.170.115.179:52461
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKO9wMmRkCAWgMC87dqe8v4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Los%20Angeles"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 103
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1132578534164066304-1145693796836839425&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 130.255.137.53:45128
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1180032815796084736-1188387259881381890&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 130.255.137.53:45128
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwK3FkZnMuB8WgsCg3YScqeYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 91.214.240.19:58987
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKOt_fPY0CAWhICjjdT6__0gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 91.214.240.19:58987
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKbl6PDNuiAWhICjjdT6__0gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 178.222.249.230:41493
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKOx8IPekh8WgsCg3YScqeYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 178.222.249.230:41493
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKfh1_7OiSAWhICjjdT6__0gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 110.34.28.30:55771
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKSdt9TV5x4WgsCg3YScqeYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 110.34.28.30:55771
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKO5t_b16R8WhICjjdT6__0gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 111.118.155.80:53990
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgKf1mZeQ1h4WgsCg3YScqeYfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 111.118.155.80:53990
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 52 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31.
# INFO: Got 52 tweets (52 new).
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 63 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Santa%20Ana"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02.
# INFO: Got 115 tweets (63 new).
# INFO: queries: ['"power outage" OR "power is out" OR "no power" OR "power\'s out" near:"Anaheim" -filter:retweets since:2019-01-01 until:2019-07-02', '"power outage" OR "power is out" OR "no power" OR "power\'s out" near:"Anaheim" -filter:retweets since:2019-07-02 until:2019-12-31']
# INFO: Querying "power outage" OR "power is out" OR "no power" OR "power's out" near:"Anaheim" -filter:retweets since:2019-01-01 until:2019-07-02
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Querying "power outage" OR "power is out" OR "no power" OR "power's out" near:"Anaheim" -filter:retweets since:2019-07-02 until:2019-12-31
# INFO: Using proxy 14.162.146.38:52385
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 14.162.146.38:52385
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1136873556401242112-1145541598123401216&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 130.255.137.53:45128
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=TWEET-1187922693431029761-1188609681817628672&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 130.255.137.53:45128
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKepqtms_CAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 91.214.240.19:58987
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKahodmWxh8WgICh-fOA5OUfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 91.214.240.19:58987
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKLVqq6d-SAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 178.222.249.230:41493
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKb16_DSlh8WgICh-fOA5OUfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 178.222.249.230:41493
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCwKL90IqN9iAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 110.34.28.30:55771
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEwKD1sPDbix8WgICh-fOA5OUfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 110.34.28.30:55771
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKPVppjU6yAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 111.118.155.80:53990
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgK_5_42O2R4WgICh-fOA5OUfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 111.118.155.80:53990
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKi5ksnb5yAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 103.75.209.75:55400
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaCgK_BuLi01x4WgICh-fOA5OUfEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02&l=en
# INFO: Using proxy 103.75.209.75:55400
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKjd45T3xiAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 89.109.239.183:47837
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 83 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-01-01%20until%3A2019-07-02.
# INFO: Got 83 tweets (83 new).
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKjxjei7oyAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 146.88.51.235:80
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAgKH1wvuQkSAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 217.182.51.229:1080
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaEgKiJ7IWckCAWgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 118.174.232.44:38093
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwKPFudGO-R8WgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 183.91.33.42:8087
# INFO: Scraping tweets from https://twitter.com/i/search/timeline?f=tweets&vertical=default&include_available_features=1&include_entities=1&reset_error_state=false&src=typd&max_position=thGAVUV0VFVBaAwLrxgf-c6h8WgMCj1aiN5f4gEjUAFQAlAFUAFQAA&q="power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31&l=en
# INFO: Using proxy 201.182.223.16:37492
# INFO: Twitter returned : 'has_more_items'
# INFO: Got 240 tweets for "power%20outage"%20OR%20"power%20is%20out"%20OR%20"no%20power"%20OR%20"power's%20out"%20near%3A"Anaheim"%20-filter%3Aretweets%20since%3A2019-07-02%20until%3A2019-12-31.
# INFO: Got 323 tweets (240 new).
# 10.132083451747894

# %%
df.shape
# Out:
# (5271, 6)

# %%
df.describe()
# Out:
#        num_retweets    num_likes
# count   5271.000000  5271.000000
# mean       1.005312     4.174730
# std        5.738281    20.565451
# min        0.000000     0.000000
# 25%        0.000000     0.000000
# 50%        0.000000     1.000000
# 75%        0.000000     3.000000
# max      143.000000   464.000000

# %%
df['location'].value_counts()
# Out:
# Oakland          1491
# San Fransisco    1373
# Los Angeles       803
# San Jose          375
# Anaheim           323
# Long Beach        270
# Sacramento        233
# San Diego         220
# Santa Ana         115
# Fresno             68
# Name: location, dtype: int64

# %%
print([tweet for tweet in df['tweet'][:5]])
# Out:
# ['Today! GWP officials will be discussing possible options for the repowering of Grayson Power Plant from 4-6 pm at Glendale City Hall. (I type as I sit in my apartment currently experiencing a power outage.) #glendal #myglendale', 'Is there a citywide power outage in Los Angeles?', 'Update... 42 minutes later still no power.', 'Indeed, every attack ever was because antifa hit you with cement, I get it.  You are sad victims with no power or strength.', 'The insta story continued through Saturday Night without a hitch.\n\nThe Sunday Matinee story just reported a mid-show power outage around 3:45pm. No further reports available at this time. \n\nIs now a good time to ask them if they left the flowers for Esmerelda? https://twitter.com/turboGFX3D/status/1144809229892501504\xa0…']

# %%
# save the dataframe file
df.to_csv('../Data/twitter.csv')
