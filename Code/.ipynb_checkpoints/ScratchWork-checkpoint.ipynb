# %% [markdown]
# # Twitter scraping

# %%
# Install Twitter Scraper
# !pip install twitterscraper
# Out:
# ...
#      |████████████████████████████████| 92kB 6.3MB/s eta 0:00:011
# ...
#   Stored in directory: /Users/Creighton/Library/Caches/pip/wheels/1b/38/dc/ca97310643483cd772d3dee2b18ce210fbca0b8e6ca01595a5
# ...
#   Stored in directory: /Users/Creighton/Library/Caches/pip/wheels/a0/b0/b2/4f80b9456b87abedbc0bf2d52235414c3467d8889be38dd472
# Successfully built twitterscraper bs4
# ...

# %%
from twitterscraper import query_tweets
import pandas as pd
import datetime, time
# Out:
# INFO: {'User-Agent': 'Mozilla/5.0 (Windows; U; Windows NT 6.1; x64; fr; rv:1.9.2.13) Gecko/20101203 Firebird/3.6.13'}

# %%
t0 = time.time()
list_o_tweet = query_tweets("blackout OR blackouts OR outage OR outages OR power outage",
                              begindate = datetime.date(2019,10,15),
                              enddate = datetime.date(2019,10,22),
                              poolsize = 2
                           )
print((time.time()-t0)/60)
# Out:
# INFO: queries: ['blackout OR blackouts OR outage OR outages OR power outage since:2019-10-15 until:2019-10-18', 'blackout OR blackouts OR outage OR outages OR power outage since:2019-10-18 until:2019-10-22']
# INFO: Querying blackout OR blackouts OR outage OR outages OR power outage since:2019-10-18 until:2019-10-22
# INFO: Querying blackout OR blackouts OR outage OR outages OR power outage since:2019-10-15 until:2019-10-18
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=blackout%20OR%20blackouts%20OR%20outage%20OR%20outages%20OR%20power%20outage%20since%3A2019-10-15%20until%3A2019-10-18&l=
# INFO: Scraping tweets from https://twitter.com/search?f=tweets&vertical=default&q=blackout%20OR%20blackouts%20OR%20outage%20OR%20outages%20OR%20power%20outage%20since%3A2019-10-18%20until%3A2019-10-22&l=
# INFO: Using proxy 187.163.36.54:35611
# INFO: Using proxy 187.163.36.54:35611
# ...

# %%
list_o_tweet[0].profile
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-0f6bf18c7ce0> in <module>
# ----> 1 list_o_tweet[0].profile
#
# AttributeError: 'Tweet' object has no attribute 'profile'

# %%
for i in range(5):
    print(list_o_tweet[i].)
    print('------------')
# Out:
# 0
# ------------
# 0
# ------------
# 0
# ------------
# 1
# ------------
# 0
# ------------
